# %%
from quocslib.optimalcontrolproblems.OneQubitProblem_2fields import OneQubit2Fields
import time

import numpy as np
import os
import sys

# %% [markdown]
# # QuOCS and Qudi

# %% [markdown]
# ### Creation of the optimization dictionary

# %% [markdown]
# The optimization dictionary contains all the settings compulsory for the optimization algorithm in order to run a proper optimization.

# %%
optimization_client_name = "test_dCRAB_2_control_fields"

# %%
optimization_dictionary = {"optimization_client_name": optimization_client_name,
                           'opti_algorithm_name': 'dCRAB', 
                           'opti_algorithm_module': 'quocslib.optimalalgorithms.dCRABAlgorithm', 
                           'opti_algorithm_class': 'DCrabAlgorithm', 
                          }

# %% [markdown]
# Number of iteration and super-iterations

# %%
# Total number of dCRAB superiteration
super_iteration_number = 5
# Maximum number of iteration per super-iteration
maximum_function_evaluations_number = 200

# %%
optimization_dictionary['algorithm_settings'] = { 'super_iteration_number': super_iteration_number, 
                                                 'maximum_function_evaluations_number': maximum_function_evaluations_number
                                                  }

# %% [markdown]
# Settings for the inner algorithm used by dCRAB

# %%
optimization_dictionary["dsm_settings"] = {'general_settings': {'dsm_name': 'nelder_mead', 'is_adaptive': False}, 
                                    'stopping_criteria': {'iterations_number': 100, 'xatol': 1e-10, 'frtol': 1e-10}}

# %% [markdown]
# ### Times

# %% [markdown]
# We can define here how many times we need to use in the optimization

# %%
time_p = {'time_name': 'time_p', 'initial_value': 201e-9}

# %%
optimization_dictionary["times"] = [time_p]

# %% [markdown]
# ### Parameters

# %%
optimization_dictionary['parameters'] = []

# %% [markdown]
# ### Pulses

# %%
pulse_amplitude = {'pulse_name': 'Amplitude', 
                   'upper_limit': 0.25, 
                   'lower_limit': -0.25, 
                   'bins_number': 1001, 
                   'time_name': 'time_p', 
                   'amplitude_variation': 0.04, 
                   'basis': {'basis_name': 'Fourier', 
                             'basis_class': 'Fourier', 
                             'basis_module': 'quocslib.pulses.basis.Fourier', 
                             'basis_vector_number': 2, 
                             'random_super_parameter_distribution': 
                             {'distribution_name': 'Uniform', 'distribution_class': 'Uniform', 
                                   'distribution_module': 'quocslib.pulses.superparameter.Uniform', 
                                   'lower_limit': 0.01, 'upper_limit': 7.0}
                            }, 
                   'scaling_function': {'function_type': 'lambda_function', 'lambda_function': 'lambda t: 1.0 + 0.0*t'}, 
                   'initial_guess': {'function_type': 'lambda_function', 'lambda_function': 'lambda t: np.pi/3 + 0.0*t'}
                  }

# %%
pulse_phase = {'pulse_name': 'Phase', 
               'upper_limit': 10, 
               'lower_limit': -10, 
               'bins_number': 1001, 
               'time_name': 'time_p', 
               'amplitude_variation': 0.5, 
               'basis': {'basis_name': 'Fourier', 
                         'basis_class': 'Fourier', 
                         'basis_module': 'quocslib.pulses.basis.Fourier', 
                         'basis_vector_number': 2, 
                         'random_super_parameter_distribution': 
                         {'distribution_name': 'Uniform', 'distribution_class': 'Uniform', 
                          'distribution_module': 'quocslib.pulses.superparameter.Uniform', 
                          'lower_limit': 0.01, 'upper_limit': 7.0}}, 
               'scaling_function': {'function_type': 'lambda_function', 'lambda_function': 'lambda t: 1.0 + 0.0*t'}, 
               'initial_guess': {'function_type': 'lambda_function', 'lambda_function': 'lambda t: 0.0*t'}
              }

# %%
optimization_dictionary['pulses'] = [pulse_amplitude, pulse_phase]

# %% [markdown]
# ### Put all together and get ready to start the optimization with Qudi-QuOCS

# %%
opti_comm_dict = {"optimization_dictionary": optimization_dictionary}

# %% [markdown]
# Load the optimization algorithm into the optimization logic and display it into the GUI

# %%
optimizationlogic.load_opti_comm_dict(opti_comm_dict)

# %% [markdown]
# #### Important: If the GUI is not showing the optimization dictionary, restart the Kernel

# %% [markdown]
# Print the optimization dictionary also here

# %%
optimalcontrol.opti_comm_dict

# %%
######################################################################################################
# Parameters and Settings
######################################################################################################

# runtime of the experiment
runtime = 5

# parameter to stop the experiment if its set to False in the console
pulsedmasterlogic.globalrun = True

# Dictonary containing the general measurement parameters for the predefined measurements
globaldict = pulsedmasterlogic.generation_parameters
globaldict["laser_channel"] = "d_ch1" 
globaldict["sync_channel"] = "d_ch2" 
globaldict["gate_channel"] = "d_ch1" 
globaldict["microwave_channel"] = "a_ch1"
globaldict["microwave_amplitude"] = 0
globaldict["microwave_frequency"] = 1.586462e9
globaldict["rabi_period"] = 71.55e-9
globaldict["laser_length"] = 12e-06
globaldict["laser_delay"] = 0
globaldict["wait_time"] = 6e-06
globaldict["analog_trigger_voltage"] = 0.0

# load the general measurement parameters for the predefined measurements
pulsedmasterlogic.set_generation_parameters(globaldict)

# tell the measurement gui how the sequence looks
pulsed_settings = dict()
pulsed_settings['invoke_settings'] = True
pulsedmasterlogic.set_measurement_settings(pulsed_settings)

# make sure everything is finished
time.sleep(5)

# how the laser response is analyzed    
pulsedmasterlogic.set_analysis_settings(method = 'mean_ref_nvision')
pulsedmasterlogic.set_analysis_settings(signal_start = 656e-9)
pulsedmasterlogic.set_analysis_settings(signal_end = 13.07e-6)
pulsedmasterlogic.set_analysis_settings(norm_start = 13.152e-6)
pulsedmasterlogic.set_analysis_settings(norm_end = 13.92e-6)
pulsedmasterlogic.set_extraction_settings(method = 'hand_through')


# This section is devoted to the initialization in the pulsed logic and optimization logic of the main
# settings and parameters to be usde in the creation ofthe pulse sequence and the optimization
# Iteration, controls and figure of merit to compare with QuOCS
# Just an example for debug
qubit = OneQubit2Fields()

######################################################################################################
# Measurement
######################################################################################################
optimalcontrol.start_optimization()

# Just a time to check for latent time
last_time_fom = time.time()
# repeat the whole process until its manually stopped or QuOCS finsihed the optimization
# Wait few seconds before starting to get and return data
while not optimizationlogic.handle_exit_obj.is_user_running:
    time.sleep(0.1)
    if (time.time() - last_time_fom) > 30:
        print("Problem at the beginning! Surpassed the 30 secs")
        break

# print("Check before the loop starts: {0}".format(optimizationlogic.handle_exit_obj.is_user_running))
while  optimizationlogic.handle_exit_obj.is_user_running == True:
    # wait until QuOCS optimizes the controls
    # print("Wait until the controls logic gives the controls")
    while not controlslogic.are_pulses_calculated:
        time.sleep(0.1)
        # If the waiting time exceed 10 seconds left stop the optimization
        if time.time() - last_time_fom > 20:
            print("Too much time... Exit!")
            optimizationlogic.handle_exit_obj.is_user_running = False
            break
            
    # If time exceeded, exit from the while loop and give a very high fom to the optimization algorithm
    # and status code -1, to interrupt the optimization smoothly
    if optimizationlogic.handle_exit_obj.is_user_running == False:
        print('Stopping the measurement!')
        # Update the pulse with the maximum number
        fomlogic.update_fom(10**10, status_code=-1)
        break
    #######################################################################################################
    # Get the Controls
    #######################################################################################################
    # Change the status of control calculations to avoid to evaluate the fom twice with the same controls
    controlslogic.are_pulses_calculated = False
    # Get the controls from the controls logic
    pulses, timegrids, parameters = controlslogic.pulses, controlslogic.timegrids, controlslogic.parameters
    #######################################################################################################
    # Perform the measurement
    #######################################################################################################
    # save the pulses as .txt files (predefined methods doesn't allow us to upload a numpy array as 
    # parameter)
    np.savetxt(r'C:\Users\Mesoscopic\Desktop\quocs_pulses\amplitude.txt',np.column_stack((timegrids[0], pulses[0])))
    np.savetxt(r'C:\Users\Mesoscopic\Desktop\quocs_pulses\phase.txt',np.column_stack((timegrids[0], pulses[1])))
    time.sleep(0.1)
    
    # Dictonary containing the measurement parameters of the specific sequence
    dictparamsall = pulsedmasterlogic.generate_method_params
    dictparams_oc = dictparamsall["quocs_pi_optimization"]
    dictparams_oc["name"] = 'quocs' # load it into the second segment of the AWG
    dictparams_oc["length"] = 200e-9
    dictparams_oc["filename_amplitude"] = r"amplitude"
    dictparams_oc["filename_phase"] = r"phase"
    dictparams_oc["folder_path"] = r"C:\Users\Mesoscopic\Desktop\quocs_pulses"
    dictparams_oc["num_of_points"] = 1 

    # generate the sequence
    pulsedmasterlogic.generate_predefined_sequence('quocs_pi_optimization',kwarg_dict = dictparams_oc)

    # sample & upload the sequence
    time.sleep(1)

    pulsedmasterlogic.sample_ensemble(dictparams_oc["name"],True)
    while pulsedmasterlogic.status_dict['sampload_busy']:
        
        time.sleep(0.5)
        
        #print('Uploading sequence ', dictparams_oc["name"],  '...')
        
        # option to stop the measurement
        if pulsedmasterlogic.globalrun == False:
            break   

    #print('Finished uploading', dictparams_oc["name"], '!')
         
    # make sure everything is finished (crucial)
    time.sleep(2)#time.sleep(5)    

#########################################################################
#should work but dont test remotely
####################################################################
    # start the measurement
    print('Starting the measurement!')
    pulsedmasterlogic.toggle_pulsed_measurement(True)
    time.sleep(1)
    
    # make sure the measurement started
    while not pulsedmasterlogic.status_dict['measurement_running']:
        time.sleep(0.1)

    measurement_start_time = time.time()
    
    while time.time() <= measurement_start_time + runtime:
        time.sleep(0.2)
        
        # option to stop the measurement
        if pulsedmasterlogic.globalrun == False:
            print('Stopping the measurement!')
            break
       
    # option to stop the measurement
    if pulsedmasterlogic.globalrun == False:
        print('Stopping the measurement!')
        pulsedmasterlogic.toggle_pulsed_measurement(False)
        break
        
    time.sleep(1)
            
    # Stop the measurement
    pulsedmasterlogic.toggle_pulsed_measurement(False)
    
    # Make sure it stopped (Wait until the Picoscope card sends the data)
    while pulsedmasterlogic.status_dict['measurement_running']:
        time.sleep(0.1)

    # calculate the fom
    fom = pulsedmeasurementlogic.signal_data[1,:][1] - pulsedmeasurementlogic.signal_data[1,:][0]
        
    #print('Measurement finished!')       

    #
    #######################################################################################################
    # Calculate the figure of merit
    #######################################################################################################
    # calculate the Figure of Merit
    #fom = qubit.get_FoM(pulses, timegrids, parameters)["FoM"]
    #######################################################################################################
    # Return the figure of merit
    #######################################################################################################
    # Update the figure of merit to the fom logic
    fomlogic.update_fom(fom, status_code=0)
    # update the last time the fom is calculated
    last_time_fom = time.time()
    #######################################################################################################
    # Optional part
    #######################################################################################################
    # Print the data just for debug purpose
    print("FoM: {0}, status_code: {1}".format(fom, 0))
print("Optimization finished")
# Out:
# Starting the measurement!
# FoM: -0.015289641602592607, status_code: 0
# Starting the measurement!
# FoM: -0.016437891581778552, status_code: 0
# Starting the measurement!
# FoM: -0.018781177891339595, status_code: 0
# Starting the measurement!
# FoM: -0.017883232213198985, status_code: 0
# Starting the measurement!
# FoM: -0.017567923961351206, status_code: 0
# Starting the measurement!
# FoM: -0.016458923616951115, status_code: 0
# Starting the measurement!
# FoM: -0.01442441935783667, status_code: 0
# Starting the measurement!
# FoM: -0.006167154415236742, status_code: 0
# Starting the measurement!
# FoM: -0.02023123944428573, status_code: 0
# Starting the measurement!
# FoM: -0.016903885371748695, status_code: 0
# Starting the measurement!
# FoM: -0.022709683472993736, status_code: 0
# Starting the measurement!
# FoM: -0.009559524768762984, status_code: 0
# Starting the measurement!
# FoM: -0.02069061831181762, status_code: 0
# Starting the measurement!
# FoM: -0.021079647401554102, status_code: 0
# Starting the measurement!
# FoM: -0.021216291245479413, status_code: 0
# Starting the measurement!
# FoM: -0.007791994199076946, status_code: 0
# Starting the measurement!
# FoM: -0.02198825268367166, status_code: 0
# Starting the measurement!
# FoM: -0.021701434774535677, status_code: 0
# Starting the measurement!
# FoM: -0.020333106851601834, status_code: 0
# Starting the measurement!
# FoM: -0.018520127843438594, status_code: 0
# Starting the measurement!
# FoM: -0.019679437533307254, status_code: 0
# Starting the measurement!
# FoM: -0.021046591766820888, status_code: 0
# Starting the measurement!
# FoM: -0.01848814943860211, status_code: 0
# Starting the measurement!
# FoM: -0.02109031660205607, status_code: 0
# Starting the measurement!
# FoM: -0.01829927052144531, status_code: 0
# Starting the measurement!
# FoM: -0.02172802770023108, status_code: 0
# Starting the measurement!
# FoM: -0.019588808299255245, status_code: 0
# Starting the measurement!
# FoM: -0.021224809048669746, status_code: 0
# Starting the measurement!
# FoM: -0.019941133580070103, status_code: 0
# Starting the measurement!
# FoM: -0.021756590606721415, status_code: 0
# Starting the measurement!
# FoM: -0.019157379268514685, status_code: 0
# Starting the measurement!
# FoM: -0.021678001640221045, status_code: 0
# Starting the measurement!
# FoM: -0.02027043660265404, status_code: 0
# Starting the measurement!
# FoM: -0.02131804087163769, status_code: 0
# Starting the measurement!
# FoM: -0.021492379283589602, status_code: 0
# Starting the measurement!
# FoM: -0.02169468765928073, status_code: 0
# Starting the measurement!
# FoM: -0.022567235529139085, status_code: 0
# Starting the measurement!
# FoM: -0.020127720189693554, status_code: 0
# Starting the measurement!
# FoM: -0.021953768079790215, status_code: 0
# Starting the measurement!
# FoM: -0.02168434735405278, status_code: 0
# Starting the measurement!
# FoM: -0.021783070595282394, status_code: 0
# Starting the measurement!
# FoM: -0.02159199663675715, status_code: 0
# Starting the measurement!
# FoM: -0.02147558437651509, status_code: 0
# Starting the measurement!
# FoM: -0.021977678812097445, status_code: 0
# Starting the measurement!
# FoM: -0.02025848971473254, status_code: 0
# Starting the measurement!
# FoM: -0.022834559739250637, status_code: 0
# Starting the measurement!
# FoM: -0.020817091398399046, status_code: 0
# Starting the measurement!
# FoM: -0.020234726624959842, status_code: 0
# Starting the measurement!
# FoM: -0.0203303784814437, status_code: 0
# Starting the measurement!
# FoM: -0.020426818296151228, status_code: 0
# Starting the measurement!
# FoM: -0.021151999505905628, status_code: 0
# Starting the measurement!
# FoM: -0.02236486808789173, status_code: 0
# Starting the measurement!
# FoM: -0.023070451826897376, status_code: 0
# Starting the measurement!
# FoM: -0.016469794855226816, status_code: 0
# Starting the measurement!
# FoM: -0.023408327484697677, status_code: 0
# Starting the measurement!
# FoM: -0.02101073167939227, status_code: 0
# Starting the measurement!
# FoM: -0.02277500723207393, status_code: 0
# Starting the measurement!
# FoM: -0.022628471919505122, status_code: 0
# Starting the measurement!
# FoM: -0.021286231764306773, status_code: 0
# Starting the measurement!
# FoM: -0.02313774839868199, status_code: 0
# Starting the measurement!
# FoM: -0.020570233388118142, status_code: 0
# Starting the measurement!
# FoM: -0.022992093451478013, status_code: 0
# Starting the measurement!
# FoM: -0.020948870576087297, status_code: 0
# Starting the measurement!
# FoM: -0.02300670652965109, status_code: 0
# Starting the measurement!
# FoM: -0.022602455902250962, status_code: 0
# Starting the measurement!
# FoM: -0.023327529296770955, status_code: 0
# Starting the measurement!
# FoM: -0.02401696781901741, status_code: 0
# Starting the measurement!
# FoM: -0.023587355757933248, status_code: 0
# Starting the measurement!
# FoM: -0.02303197449359451, status_code: 0
# Starting the measurement!
# FoM: -0.022008286320967962, status_code: 0
# Starting the measurement!
# FoM: -0.023551085030493857, status_code: 0
# Starting the measurement!
# FoM: -0.02281100215272025, status_code: 0
# Starting the measurement!
# FoM: -0.023534633793543924, status_code: 0
# Starting the measurement!
# FoM: -0.023598675485055898, status_code: 0
# Starting the measurement!
# FoM: -0.02184211886769538, status_code: 0
# Starting the measurement!
# FoM: -0.02312441843128543, status_code: 0
# Starting the measurement!
# FoM: -0.023348819557885925, status_code: 0
# Starting the measurement!
# FoM: -0.0232840864515379, status_code: 0
# Starting the measurement!
# FoM: -0.023273000446571324, status_code: 0
# Starting the measurement!
# FoM: -0.02344657229079683, status_code: 0
# Starting the measurement!
# FoM: -0.023023488868029185, status_code: 0
# Starting the measurement!
# FoM: -0.023662909497858764, status_code: 0
# Starting the measurement!
# FoM: -0.02354113322500717, status_code: 0
# Starting the measurement!
# FoM: -0.02315220284698949, status_code: 0
# Starting the measurement!
# FoM: -0.02333336201138081, status_code: 0
# Starting the measurement!
# FoM: -0.023508709338953437, status_code: 0
# Starting the measurement!
# FoM: -0.023302028725239787, status_code: 0
# Starting the measurement!
# FoM: -0.023238125843883517, status_code: 0
# Starting the measurement!
# FoM: -0.023545274657743587, status_code: 0
# Starting the measurement!
# FoM: -0.023471065966844007, status_code: 0
# Starting the measurement!
# FoM: -0.02349811174065508, status_code: 0
# Starting the measurement!
# FoM: -0.02323699514380506, status_code: 0
# Starting the measurement!
# FoM: -0.023188697167261685, status_code: 0
# Starting the measurement!
# FoM: -0.023263349127724764, status_code: 0
# Starting the measurement!
# FoM: -0.02348073430054587, status_code: 0
# Starting the measurement!
# FoM: -0.02317892618003814, status_code: 0
# Starting the measurement!
# FoM: -0.02321872110669687, status_code: 0
# Starting the measurement!
# FoM: -0.02337080914822587, status_code: 0
# Starting the measurement!
# FoM: -0.023256089970870253, status_code: 0
# Starting the measurement!
# FoM: -0.023218995576533286, status_code: 0
# Starting the measurement!
# FoM: -0.02309760344902223, status_code: 0
# Starting the measurement!
# FoM: -0.023096688245274666, status_code: 0
# Starting the measurement!
# FoM: -0.022673835554431365, status_code: 0
# Starting the measurement!
# FoM: -0.02276588641625288, status_code: 0
# Starting the measurement!
# FoM: -0.022835953845242396, status_code: 0
# Starting the measurement!
# FoM: -0.02277868650848336, status_code: 0
# Starting the measurement!
# FoM: -0.02293255934622196, status_code: 0
# Starting the measurement!
# FoM: -0.022489966549331553, status_code: 0
# Starting the measurement!
# FoM: -0.022903439507653944, status_code: 0
# Starting the measurement!
# FoM: -0.02291392244167323, status_code: 0
# Starting the measurement!
# FoM: -0.022862548740963606, status_code: 0
# Starting the measurement!
# FoM: -0.022784457461620167, status_code: 0
# Starting the measurement!
# FoM: -0.02273169846258849, status_code: 0
# Starting the measurement!
# FoM: -0.022674828405790826, status_code: 0
# Starting the measurement!
# FoM: -0.022589474569510437, status_code: 0
# Starting the measurement!
# FoM: -0.02285405849701383, status_code: 0
# Starting the measurement!
# FoM: -0.022565314777205803, status_code: 0
# Starting the measurement!
# FoM: -0.02287799613744712, status_code: 0
# Starting the measurement!
# FoM: -0.02273996232868558, status_code: 0
# Starting the measurement!
# FoM: -0.02253052832218483, status_code: 0
# Starting the measurement!
# FoM: -0.02253378431093389, status_code: 0
# Starting the measurement!
# FoM: -0.022399759366909522, status_code: 0
# Starting the measurement!
# FoM: -0.022444314038868374, status_code: 0
# Starting the measurement!
# FoM: -0.022548798641316647, status_code: 0
# Starting the measurement!
# FoM: -0.022469423670288813, status_code: 0
# Starting the measurement!
# FoM: -0.022455547803809095, status_code: 0
# Starting the measurement!
# FoM: -0.022710879993782962, status_code: 0
# Starting the measurement!
# FoM: -0.0225023363249518, status_code: 0
# Starting the measurement!
# FoM: -0.02248971805259492, status_code: 0
# Starting the measurement!
# FoM: -0.022667415138098446, status_code: 0
# Starting the measurement!
# FoM: -0.022441470902963445, status_code: 0
# Starting the measurement!
# FoM: -0.022570340886173823, status_code: 0
# Starting the measurement!
# FoM: -0.02244429597580011, status_code: 0
# Starting the measurement!
# FoM: -0.022512403191679464, status_code: 0
# Starting the measurement!
# FoM: -0.02277186364653394, status_code: 0
# Starting the measurement!
# FoM: -0.022213839422701498, status_code: 0
# Starting the measurement!
# FoM: -0.02254889943452809, status_code: 0
# Starting the measurement!
# FoM: -0.022332344028540452, status_code: 0
# Starting the measurement!
# FoM: -0.022239210090486128, status_code: 0
# Starting the measurement!
# FoM: -0.02214674517207771, status_code: 0
# Starting the measurement!
# FoM: -0.021954273123978574, status_code: 0
# Starting the measurement!
# FoM: -0.022142483465220852, status_code: 0
# Starting the measurement!
# FoM: -0.022357022195256482, status_code: 0
# Starting the measurement!
# FoM: -0.022563081431792975, status_code: 0
# Starting the measurement!
# FoM: -0.022437894776868417, status_code: 0
# Starting the measurement!
# FoM: -0.022374092860464545, status_code: 0
# Starting the measurement!
# FoM: -0.02200456272497031, status_code: 0
# Starting the measurement!
# FoM: -0.022065323391203484, status_code: 0
# Starting the measurement!
# FoM: -0.022077156878030246, status_code: 0
# Starting the measurement!
# FoM: -0.022113404878515985, status_code: 0
# Starting the measurement!
# FoM: -0.022131047888302113, status_code: 0
# Starting the measurement!
# FoM: -0.022093005010335842, status_code: 0
# Starting the measurement!
# FoM: -0.022077533961333606, status_code: 0
# Starting the measurement!
# FoM: -0.022093997573384372, status_code: 0
# Starting the measurement!
# FoM: -0.022218086149529692, status_code: 0
# Starting the measurement!
# FoM: -0.022059422476323864, status_code: 0
# Starting the measurement!
# FoM: -0.022138466121029876, status_code: 0
# Starting the measurement!
# FoM: -0.022055778888873445, status_code: 0
# Starting the measurement!
# FoM: -0.022223142125262663, status_code: 0
# Starting the measurement!
# FoM: -0.022027187039943108, status_code: 0
# Starting the measurement!
# FoM: -0.021798579548357067, status_code: 0
# Starting the measurement!
# FoM: -0.022363919744191052, status_code: 0
# Starting the measurement!
# FoM: -0.02215124980970329, status_code: 0
# Starting the measurement!
# FoM: -0.021870901797382714, status_code: 0
# Starting the measurement!
# FoM: -0.022050533413507156, status_code: 0
# Starting the measurement!
# FoM: -0.021961474733413477, status_code: 0
# Starting the measurement!
# FoM: -0.0220725692816518, status_code: 0
# Starting the measurement!
# FoM: -0.021854539754392777, status_code: 0
# Starting the measurement!
# FoM: -0.022016708271595964, status_code: 0
# Starting the measurement!
# FoM: -0.021502644268228455, status_code: 0
# Starting the measurement!
# FoM: -0.022020502995783175, status_code: 0
# Starting the measurement!
# FoM: -0.02188841614850745, status_code: 0
# Starting the measurement!
# FoM: -0.021846748363852475, status_code: 0
# Starting the measurement!
# FoM: -0.022094201262534696, status_code: 0
# Starting the measurement!
# FoM: -0.021672123121262765, status_code: 0
# Starting the measurement!
# FoM: -0.02161414522847105, status_code: 0
# Starting the measurement!
# FoM: -0.02174869034252369, status_code: 0
# Starting the measurement!
# FoM: -0.021412125119013026, status_code: 0
# Starting the measurement!
# FoM: -0.02182191431366598, status_code: 0
# Starting the measurement!
# FoM: -0.02155002844151077, status_code: 0
# Starting the measurement!
# FoM: -0.021658218577541022, status_code: 0
# Starting the measurement!
# FoM: -0.02173291926209986, status_code: 0
# Starting the measurement!
# FoM: -0.021599791932214285, status_code: 0
# Starting the measurement!
# FoM: -0.02158417945875568, status_code: 0
# Starting the measurement!
# FoM: -0.0217830611995925, status_code: 0
# Starting the measurement!
# FoM: -0.02142221027179303, status_code: 0
# Starting the measurement!
# FoM: -0.021573087442105843, status_code: 0
# Starting the measurement!
# FoM: -0.021799326347491377, status_code: 0
# Starting the measurement!
# FoM: -0.021499631203467318, status_code: 0
# Starting the measurement!
# FoM: -0.02152602448556029, status_code: 0
# Starting the measurement!
# FoM: -0.021424394778028155, status_code: 0
# Starting the measurement!
# FoM: -0.02146145955013168, status_code: 0
# Starting the measurement!
# FoM: -0.021563235013388193, status_code: 0
# Starting the measurement!
# FoM: -0.02144909471964762, status_code: 0
# Starting the measurement!
# FoM: -0.02141995760304649, status_code: 0
# Starting the measurement!
# FoM: -0.021439714039387048, status_code: 0
# Starting the measurement!
# FoM: -0.02156020503919953, status_code: 0
# Starting the measurement!
# FoM: -0.021565425944567673, status_code: 0
# Starting the measurement!
# FoM: -0.021352968122428595, status_code: 0
# Starting the measurement!
# FoM: -0.02153766770419896, status_code: 0
# Starting the measurement!
# FoM: -0.02128673304985751, status_code: 0
# Starting the measurement!
# FoM: -0.021410673515866563, status_code: 0
# Starting the measurement!
# FoM: -0.021166213448650217, status_code: 0
# Starting the measurement!
# FoM: -0.02127579986071393, status_code: 0
# Starting the measurement!
# FoM: -0.0215747988781696, status_code: 0
# Starting the measurement!
# FoM: -0.01618969819801086, status_code: 0
# Starting the measurement!
# FoM: -0.011589234069615983, status_code: 0
# Starting the measurement!
# FoM: -0.008577783924042959, status_code: 0
# Starting the measurement!
# FoM: -0.014787346494256282, status_code: 0
# Starting the measurement!
# FoM: -0.01956665387918466, status_code: 0
# Starting the measurement!
# FoM: -0.021238902657252368, status_code: 0
# Starting the measurement!
# FoM: -0.0209669500180083, status_code: 0
# Starting the measurement!
# FoM: -0.01777366410910286, status_code: 0
# Starting the measurement!
# FoM: -0.020417883313000762, status_code: 0
# Starting the measurement!
# FoM: -0.020824160523939206, status_code: 0
# Starting the measurement!
# FoM: -0.021137402905076597, status_code: 0
# Starting the measurement!
# FoM: -0.01857922197391082, status_code: 0
# Starting the measurement!
# FoM: -0.021926451509765688, status_code: 0
# Starting the measurement!
# FoM: -0.012205273718631449, status_code: 0
# Starting the measurement!
# FoM: -0.020925987231394716, status_code: 0
# Starting the measurement!
# FoM: -0.021503426769825973, status_code: 0
# Starting the measurement!
# FoM: -0.02138322459940123, status_code: 0
# Starting the measurement!
# FoM: -0.02128545761480871, status_code: 0
# Starting the measurement!
# FoM: -0.021725115565405795, status_code: 0
# Starting the measurement!
# FoM: -0.0221278564322257, status_code: 0
# Starting the measurement!
# FoM: -0.021496712641567717, status_code: 0
# Starting the measurement!
# FoM: -0.021675742968561562, status_code: 0
# Starting the measurement!
# FoM: -0.02141897926706615, status_code: 0
# Starting the measurement!
# FoM: -0.0216019006195044, status_code: 0
# Starting the measurement!
# FoM: -0.022018820447511467, status_code: 0
# Starting the measurement!
# FoM: -0.007846286701562066, status_code: 0
# Starting the measurement!
# FoM: -0.021282283332245022, status_code: 0
# Starting the measurement!
# FoM: -0.02231702309992256, status_code: 0
# Starting the measurement!
# FoM: -0.021821318206997176, status_code: 0
# Starting the measurement!
# FoM: -0.021734142253298727, status_code: 0
# Starting the measurement!
# FoM: -0.02201874900217482, status_code: 0
# Starting the measurement!
# FoM: -0.022247972260903692, status_code: 0
# Starting the measurement!
# FoM: -0.021976187491767885, status_code: 0
# Starting the measurement!
# FoM: -0.021514141837296052, status_code: 0
# Starting the measurement!
# FoM: -0.021762430688916257, status_code: 0
# Starting the measurement!
# FoM: -0.02204437592804298, status_code: 0
# Starting the measurement!
# FoM: -0.022203069797011366, status_code: 0
# Starting the measurement!
# FoM: -0.020561749918715067, status_code: 0
# Starting the measurement!
# FoM: -0.02178597905837598, status_code: 0
# Starting the measurement!
# FoM: -0.021642018204809155, status_code: 0
# Starting the measurement!
# FoM: -0.0221762976665405, status_code: 0
# Starting the measurement!
# FoM: -0.02191877172586354, status_code: 0
# Starting the measurement!
# FoM: -0.02211432425953641, status_code: 0
# Starting the measurement!
# FoM: -0.02197061600493211, status_code: 0
# Starting the measurement!
# FoM: -0.02177360320804178, status_code: 0
# Starting the measurement!
# FoM: -0.02165930111287473, status_code: 0
# Starting the measurement!
# FoM: -0.021879118599432368, status_code: 0
# Starting the measurement!
# FoM: -0.021924975873938712, status_code: 0
# Starting the measurement!
# FoM: -0.021797533003713454, status_code: 0
# Starting the measurement!
# FoM: -0.021954152644884206, status_code: 0
# Starting the measurement!
# FoM: -0.02162407734585292, status_code: 0
# Starting the measurement!
# FoM: -0.021910680468724797, status_code: 0
# Starting the measurement!
# FoM: -0.02182220311249161, status_code: 0
# Starting the measurement!
# FoM: -0.02177608896580696, status_code: 0
# Starting the measurement!
# FoM: -0.021869311106677558, status_code: 0
# Starting the measurement!
# FoM: -0.021864951920522624, status_code: 0
# Starting the measurement!
# FoM: -0.02193506172584414, status_code: 0
# Starting the measurement!
# FoM: -0.02191144112876109, status_code: 0
# Starting the measurement!
# FoM: -0.021605324609693, status_code: 0
# Starting the measurement!
# FoM: -0.021999633342702718, status_code: 0
# Starting the measurement!
# FoM: -0.021917424086545623, status_code: 0
# Starting the measurement!
# FoM: -0.02182543367792733, status_code: 0
# Starting the measurement!
# FoM: -0.02202960803859888, status_code: 0
# Starting the measurement!
# FoM: -0.022012114051630394, status_code: 0
# Starting the measurement!
# FoM: -0.021704633935585305, status_code: 0
# Starting the measurement!
# FoM: -0.021835644530618148, status_code: 0
# Starting the measurement!
# FoM: -0.021920971692573676, status_code: 0
# Starting the measurement!
# FoM: -0.02194809421597821, status_code: 0
# Starting the measurement!
# FoM: -0.02179981068144876, status_code: 0
# Starting the measurement!
# FoM: -0.021620156456292117, status_code: 0
# Starting the measurement!
# FoM: -0.021713372402818232, status_code: 0
# Starting the measurement!
# FoM: -0.021447299458929092, status_code: 0
# Starting the measurement!
# FoM: -0.02195750509161576, status_code: 0
# Starting the measurement!
# FoM: -0.021899879069387063, status_code: 0
# Starting the measurement!
# FoM: -0.021900414173099292, status_code: 0
# Starting the measurement!
# FoM: -0.021706511487916025, status_code: 0
# Starting the measurement!
# FoM: -0.021821027625751, status_code: 0
# Starting the measurement!
# FoM: -0.02189795242955217, status_code: 0
# Starting the measurement!
# FoM: -0.021991977447810895, status_code: 0
# Starting the measurement!
# FoM: -0.02172792121591538, status_code: 0
# Starting the measurement!
# FoM: -0.021746644014412397, status_code: 0
# Starting the measurement!
# FoM: -0.021592846891414386, status_code: 0
# Starting the measurement!
# FoM: -0.02139180341112734, status_code: 0
# Starting the measurement!
# FoM: -0.021788377879279452, status_code: 0
# Starting the measurement!
# FoM: -0.0215895824851986, status_code: 0
# Starting the measurement!
# FoM: -0.021825495515012228, status_code: 0
# Starting the measurement!
# FoM: -0.021665439456346136, status_code: 0
# Starting the measurement!
# FoM: -0.021895685265776677, status_code: 0
# Starting the measurement!
# FoM: -0.021626510443894742, status_code: 0
# Starting the measurement!
# FoM: -0.0216398720077019, status_code: 0
# Starting the measurement!
# FoM: -0.021965956630387695, status_code: 0
# Starting the measurement!
# FoM: -0.02173946006609484, status_code: 0
# Starting the measurement!
# FoM: -0.021856568550531752, status_code: 0
# Starting the measurement!
# FoM: -0.021553194019497512, status_code: 0
# Starting the measurement!
# FoM: -0.021938828279532308, status_code: 0
# Starting the measurement!
# FoM: -0.021737520641724517, status_code: 0
# Starting the measurement!
# FoM: -0.02173991153716015, status_code: 0
# Starting the measurement!
# FoM: -0.021770448382117946, status_code: 0
# Starting the measurement!
# FoM: -0.021835131459297497, status_code: 0
# Starting the measurement!
# FoM: -0.02182085287687796, status_code: 0
# Starting the measurement!
# FoM: -0.021459564803845588, status_code: 0
# Starting the measurement!
# FoM: -0.021880830696371922, status_code: 0
# Starting the measurement!
# FoM: -0.021822289808429374, status_code: 0
# Starting the measurement!
# FoM: -0.021753182340497834, status_code: 0
# Starting the measurement!
# FoM: -0.021450704518478525, status_code: 0
# Starting the measurement!
# FoM: -0.021662442577691232, status_code: 0
# Starting the measurement!
# FoM: -0.021503672648893857, status_code: 0
# Starting the measurement!
# FoM: -0.021716872304447632, status_code: 0
# Starting the measurement!
# FoM: -0.02179088805693752, status_code: 0
# Starting the measurement!
# FoM: -0.02182368468147733, status_code: 0
# Starting the measurement!
# FoM: -0.02183819213292948, status_code: 0
# Starting the measurement!
# FoM: -0.02154480229311395, status_code: 0
# Starting the measurement!
# FoM: -0.021724850131017548, status_code: 0
# Starting the measurement!
# FoM: -0.02166029526648483, status_code: 0
# Starting the measurement!
# FoM: -0.02171709629769536, status_code: 0
# Starting the measurement!
# FoM: -0.02157903743858458, status_code: 0
# Starting the measurement!
# FoM: -0.021558325043607218, status_code: 0
# Starting the measurement!
# FoM: -0.021549162727981463, status_code: 0
# Starting the measurement!
# FoM: -0.021576476172042724, status_code: 0
# Starting the measurement!
# FoM: -0.021409992079889917, status_code: 0
# Starting the measurement!
# FoM: -0.021510579665805163, status_code: 0
# Starting the measurement!
# FoM: -0.021564511509220563, status_code: 0
# Starting the measurement!
# FoM: -0.021739298606605284, status_code: 0
# Starting the measurement!
# FoM: -0.021432939973830778, status_code: 0
# Starting the measurement!
# FoM: -0.021856608434697833, status_code: 0
# Starting the measurement!
# FoM: -0.021791775592888807, status_code: 0
# Starting the measurement!
# FoM: -0.021784620571813074, status_code: 0
# Starting the measurement!
# FoM: -0.021689891384588433, status_code: 0
# Starting the measurement!
# FoM: -0.02172169871308749, status_code: 0
# Starting the measurement!
# FoM: -0.0220339214933003, status_code: 0
# Starting the measurement!
# FoM: -0.021558264669291227, status_code: 0
# Starting the measurement!
# FoM: -0.02169397055888389, status_code: 0
# Starting the measurement!
# FoM: -0.021674910012601467, status_code: 0
# Starting the measurement!
# FoM: -0.021964236310942464, status_code: 0
# Starting the measurement!
# FoM: -0.021740253394053943, status_code: 0
# Starting the measurement!
# FoM: -0.021697908877615024, status_code: 0
# Starting the measurement!
# FoM: -0.021467571547410857, status_code: 0
# Starting the measurement!
# FoM: -0.02179123091829427, status_code: 0
# Starting the measurement!
# FoM: -0.021800106502234184, status_code: 0
# Starting the measurement!
# FoM: -0.021930461267639645, status_code: 0
# Starting the measurement!
# FoM: -0.021927084498832627, status_code: 0
# Starting the measurement!
# FoM: -0.021443143597691394, status_code: 0
# Starting the measurement!
# FoM: -0.021765793725530336, status_code: 0
# Starting the measurement!
# FoM: -0.02163651498312924, status_code: 0
# Starting the measurement!
# FoM: -0.021645168443814033, status_code: 0
# Starting the measurement!
# FoM: -0.02142280375631478, status_code: 0
# Starting the measurement!
# FoM: -0.02189598578720564, status_code: 0
# Starting the measurement!
# FoM: -0.02172204928441046, status_code: 0
# Starting the measurement!
# FoM: -0.021416990680466652, status_code: 0
# Starting the measurement!
# FoM: -0.021782217958861372, status_code: 0
# Starting the measurement!
# FoM: -0.021677461744097903, status_code: 0
# Starting the measurement!
# FoM: -0.021791457271270742, status_code: 0
# Starting the measurement!
# FoM: -0.02158972503721568, status_code: 0
# Starting the measurement!
# FoM: -0.021596965301629356, status_code: 0
# Starting the measurement!
# FoM: -0.021495297875979702, status_code: 0
# Starting the measurement!
# FoM: -0.021690392940347802, status_code: 0
# Starting the measurement!
# FoM: -0.021762098128263574, status_code: 0
# Starting the measurement!
# FoM: -0.021750865710627787, status_code: 0
# Starting the measurement!
# FoM: -0.02166640224899563, status_code: 0
# Starting the measurement!
# FoM: -0.02227739454247868, status_code: 0
# Starting the measurement!
# FoM: -0.021668711656369077, status_code: 0
# Starting the measurement!
# FoM: -0.022022201462430058, status_code: 0
# Starting the measurement!
# FoM: -0.021623644299494038, status_code: 0
# Starting the measurement!
# FoM: -0.02183746767444361, status_code: 0
# Starting the measurement!
# FoM: -0.02159049541326441, status_code: 0
# Starting the measurement!
# FoM: -0.021644327325214374, status_code: 0
# Starting the measurement!
# FoM: -0.021760194280453726, status_code: 0
# Starting the measurement!
# FoM: -0.021694115509375722, status_code: 0
# Starting the measurement!
# FoM: -0.021671693576790774, status_code: 0
# Starting the measurement!
# FoM: -0.02179848462769307, status_code: 0
# Starting the measurement!
# FoM: -0.02186134023491504, status_code: 0
# Starting the measurement!
# FoM: -0.021800141201510748, status_code: 0
# Starting the measurement!
# FoM: -0.021545742347639174, status_code: 0
# Starting the measurement!
# FoM: -0.021675532398274133, status_code: 0
# Starting the measurement!
# FoM: -0.02165093467226986, status_code: 0
# Starting the measurement!
# FoM: -0.021969127744360217, status_code: 0
# Starting the measurement!
# FoM: -0.021523976817296342, status_code: 0
# Starting the measurement!
# FoM: -0.021621252491808796, status_code: 0
# Starting the measurement!
# FoM: -0.021991847343527215, status_code: 0
# Starting the measurement!
# FoM: -0.021724106040901248, status_code: 0
# Starting the measurement!
# FoM: -0.021818621220610734, status_code: 0
# Starting the measurement!
# FoM: -0.021610866257191552, status_code: 0
# Starting the measurement!
# FoM: -0.021628036205736723, status_code: 0
# Starting the measurement!
# FoM: -0.02163965740892526, status_code: 0
# Starting the measurement!
# FoM: -0.022035331425237614, status_code: 0
# Starting the measurement!
# FoM: -0.021851164141456048, status_code: 0
# Starting the measurement!
# FoM: -0.02159523271929098, status_code: 0
# Starting the measurement!
# FoM: -0.021585774623986476, status_code: 0
# Starting the measurement!
# FoM: -0.021815556750340748, status_code: 0
# Starting the measurement!
# FoM: -0.021652668584625112, status_code: 0
# Starting the measurement!
# FoM: -0.021911431472452003, status_code: 0
# Starting the measurement!
# FoM: -0.021783146768321604, status_code: 0
# Starting the measurement!
# FoM: -0.021964050477043418, status_code: 0
# Starting the measurement!
# FoM: -0.02176981230828623, status_code: 0
# Starting the measurement!
# FoM: -0.021623138513323648, status_code: 0
# Starting the measurement!
# FoM: -0.021677131453257892, status_code: 0
# Starting the measurement!
# FoM: -0.021694436905652537, status_code: 0
# Starting the measurement!
# FoM: -0.02192323392262796, status_code: 0
# Starting the measurement!
# FoM: -0.021370424104586894, status_code: 0
# Starting the measurement!
# FoM: -0.02156316070934361, status_code: 0
# Starting the measurement!
# FoM: -0.02144531833830332, status_code: 0
# Starting the measurement!
# FoM: -0.01772439097156131, status_code: 0
# Starting the measurement!
# FoM: -0.015201643307062307, status_code: 0
# Starting the measurement!
# FoM: -0.0159849775743941, status_code: 0
# Starting the measurement!
# FoM: -0.020723716764573852, status_code: 0
# Starting the measurement!
# FoM: -0.017031468279799178, status_code: 0
# Starting the measurement!
# FoM: -0.011874298716521792, status_code: 0
# Starting the measurement!
# FoM: -0.021196927168583568, status_code: 0
# Starting the measurement!
# FoM: -0.012902591522737983, status_code: 0
# Starting the measurement!
# FoM: -0.021314632460397442, status_code: 0
# Starting the measurement!
# FoM: -0.019667622076545266, status_code: 0
# Starting the measurement!
# FoM: -0.02128830334958387, status_code: 0
# Starting the measurement!
# FoM: -0.021333468742794626, status_code: 0
# Starting the measurement!
# FoM: -0.020117914721352714, status_code: 0
# Starting the measurement!
# FoM: -0.021749184425180812, status_code: 0
# Starting the measurement!
# FoM: -0.020043185320881562, status_code: 0
# Starting the measurement!
# FoM: -0.021730766226055298, status_code: 0
# Starting the measurement!
# FoM: -0.019989756666184744, status_code: 0
# Starting the measurement!
# FoM: -0.021629834949807303, status_code: 0
# Starting the measurement!
# FoM: -0.021089547674202902, status_code: 0
# Starting the measurement!
# FoM: -0.021574095742148303, status_code: 0
# Starting the measurement!
# FoM: -0.021799495354413723, status_code: 0
# Starting the measurement!
# FoM: -0.021771716105104533, status_code: 0
# Starting the measurement!
# FoM: -0.021610774390994014, status_code: 0
# Starting the measurement!
# FoM: -0.021309816319312502, status_code: 0
# Starting the measurement!
# FoM: -0.021649854824255632, status_code: 0
# Starting the measurement!
# FoM: -0.021355169752400927, status_code: 0
# Starting the measurement!
# FoM: -0.021720128811287487, status_code: 0
# Starting the measurement!
# FoM: -0.021940241928928295, status_code: 0
# Starting the measurement!
# FoM: -0.02150330144517032, status_code: 0
# Starting the measurement!
# FoM: -0.021802876391669668, status_code: 0
# Starting the measurement!
# FoM: -0.021383821546238968, status_code: 0
# Starting the measurement!
# FoM: -0.021891365162083343, status_code: 0
# Starting the measurement!
# FoM: -0.02173151683866259, status_code: 0
# Starting the measurement!
# FoM: -0.02140477372707217, status_code: 0
# Starting the measurement!
# FoM: -0.021698574441107565, status_code: 0
# Starting the measurement!
# FoM: -0.02153697954854339, status_code: 0
# Starting the measurement!
# FoM: -0.02182460913448525, status_code: 0
# Starting the measurement!
# FoM: -0.021802390456804543, status_code: 0
# Starting the measurement!
# FoM: -0.02167828767413571, status_code: 0
# Starting the measurement!
# FoM: -0.021832540775978182, status_code: 0
# Starting the measurement!
# FoM: -0.021716052456186352, status_code: 0
# Starting the measurement!
# FoM: -0.021628458155820485, status_code: 0
# Starting the measurement!
# FoM: -0.02145806672455175, status_code: 0
# Starting the measurement!
# FoM: -0.02158969490100071, status_code: 0
# Starting the measurement!
# FoM: -0.02173502657052051, status_code: 0
# Starting the measurement!
# FoM: -0.02180151957446974, status_code: 0
# Starting the measurement!
# FoM: -0.021492519430804435, status_code: 0
# Starting the measurement!
# FoM: -0.021955808139487165, status_code: 0
# Starting the measurement!
# FoM: -0.021393985743781707, status_code: 0
# Starting the measurement!
# FoM: -0.021696503264622913, status_code: 0
# Starting the measurement!
# FoM: -0.02184694211042848, status_code: 0
# Starting the measurement!
# FoM: -0.021412040856289782, status_code: 0
# Starting the measurement!
# FoM: -0.021449850339733345, status_code: 0
# Starting the measurement!
# FoM: -0.02161168639780464, status_code: 0
# Starting the measurement!
# FoM: -0.021649952564646524, status_code: 0
# Starting the measurement!
# FoM: -0.02140048961786256, status_code: 0
# Starting the measurement!
# FoM: -0.021571547160271654, status_code: 0
# Starting the measurement!
# FoM: -0.021476680802807402, status_code: 0
# Starting the measurement!
# FoM: -0.02149504136092295, status_code: 0
# Starting the measurement!
# FoM: -0.02169234679889831, status_code: 0
# Starting the measurement!
# FoM: -0.021800372433017468, status_code: 0
# Starting the measurement!
# FoM: -0.021690840469787864, status_code: 0
# Starting the measurement!
# FoM: -0.02144536172749978, status_code: 0
# Starting the measurement!
# FoM: -0.021628971939871344, status_code: 0
# Starting the measurement!
# FoM: -0.021305617330877658, status_code: 0
# Starting the measurement!
# FoM: -0.021568110162196397, status_code: 0
# Starting the measurement!
# FoM: -0.021627792300484727, status_code: 0
# Starting the measurement!
# FoM: -0.02156919858343198, status_code: 0
# Starting the measurement!
# FoM: -0.021692501496260008, status_code: 0
# Starting the measurement!
# FoM: -0.021314888780929353, status_code: 0
# Starting the measurement!
# FoM: -0.02173304141952115, status_code: 0
# Starting the measurement!
# FoM: -0.021523438029773634, status_code: 0
# Starting the measurement!
# FoM: -0.02150704102497114, status_code: 0
# Starting the measurement!
# FoM: -0.021423635037588373, status_code: 0
# Starting the measurement!
# FoM: -0.021461246006159285, status_code: 0
# Starting the measurement!
# FoM: -0.021542329440551122, status_code: 0
# Starting the measurement!
# FoM: -0.021418339332528902, status_code: 0
# Starting the measurement!
# FoM: -0.02146116900169992, status_code: 0
# Starting the measurement!
# FoM: -0.021524557990992066, status_code: 0
# Starting the measurement!
# FoM: -0.021521507619704172, status_code: 0
# Starting the measurement!
# FoM: -0.02133543559014539, status_code: 0
# Starting the measurement!
# FoM: -0.021086654365863433, status_code: 0
# Starting the measurement!
# FoM: -0.02127168524424039, status_code: 0
# Starting the measurement!
# FoM: -0.021771613102073095, status_code: 0
# Starting the measurement!
# FoM: -0.021372800681019433, status_code: 0
# Starting the measurement!
# FoM: -0.021395710773635557, status_code: 0
# Starting the measurement!
# FoM: -0.021175869453243457, status_code: 0
# Starting the measurement!
# FoM: -0.021630891795674123, status_code: 0
# Starting the measurement!
# FoM: -0.02120528453087034, status_code: 0
# Starting the measurement!
# FoM: -0.02124819383296561, status_code: 0
# Starting the measurement!
# FoM: -0.021508904614563784, status_code: 0
# Starting the measurement!
# FoM: -0.021235219339309275, status_code: 0
# Starting the measurement!
# FoM: -0.021340896102012175, status_code: 0
# Starting the measurement!
# FoM: -0.02126137828461694, status_code: 0
# Starting the measurement!
# FoM: -0.021334094563895678, status_code: 0
# Starting the measurement!
# FoM: -0.021269627976272742, status_code: 0
# Starting the measurement!
# FoM: -0.021209511743068177, status_code: 0
# Starting the measurement!
# FoM: -0.021222088881923673, status_code: 0
# Starting the measurement!
# FoM: -0.02132451368721644, status_code: 0
# Starting the measurement!
# FoM: -0.021252284383962317, status_code: 0
# Starting the measurement!
# FoM: -0.02099274413362151, status_code: 0
# Starting the measurement!
# FoM: -0.02109465378272901, status_code: 0
# Starting the measurement!
# FoM: -0.020923946600101218, status_code: 0
# Starting the measurement!
# FoM: -0.021186710960725663, status_code: 0
# Starting the measurement!
# FoM: -0.021273030877743015, status_code: 0
# Starting the measurement!
# FoM: -0.02111901160626206, status_code: 0
# Starting the measurement!
# FoM: -0.021273715330349496, status_code: 0
# Starting the measurement!
# FoM: -0.021452663474490263, status_code: 0
# Starting the measurement!
# FoM: -0.02106600364391953, status_code: 0
# Starting the measurement!
# FoM: -0.021097096944235783, status_code: 0
# Starting the measurement!
# FoM: -0.02113955416257396, status_code: 0
# Starting the measurement!
# FoM: -0.021075116152120765, status_code: 0
# Starting the measurement!
# FoM: -0.02073448851360693, status_code: 0
# Starting the measurement!
# FoM: -0.02103469188151519, status_code: 0
# Starting the measurement!
# FoM: -0.020919449015876057, status_code: 0
# Starting the measurement!
# FoM: -0.02102236359519183, status_code: 0
# Starting the measurement!
# FoM: -0.020941472333180777, status_code: 0
# Starting the measurement!
# FoM: -0.021173222222796717, status_code: 0
# Starting the measurement!
# FoM: -0.021223347993157615, status_code: 0
# Starting the measurement!
# FoM: -0.02089832296250571, status_code: 0
# Starting the measurement!
# FoM: -0.02124269596671835, status_code: 0
# Starting the measurement!
# FoM: -0.02094073452877898, status_code: 0
# Starting the measurement!
# FoM: -0.02097619920589977, status_code: 0
# Starting the measurement!
# FoM: -0.02100980918466655, status_code: 0
# Starting the measurement!
# FoM: -0.021039969195150943, status_code: 0
# Starting the measurement!
# FoM: -0.02115728732172395, status_code: 0
# Starting the measurement!
# FoM: -0.020878111615115436, status_code: 0
# Starting the measurement!
# FoM: -0.020983749355528714, status_code: 0
# Starting the measurement!
# FoM: -0.02079092440078567, status_code: 0
# Starting the measurement!
# FoM: -0.02087111866439373, status_code: 0
# Starting the measurement!
# FoM: -0.02067870165789565, status_code: 0
# Starting the measurement!
# FoM: -0.020717579002072162, status_code: 0
# Starting the measurement!
# FoM: -0.020876316270488582, status_code: 0
# Starting the measurement!
# FoM: -0.020916176863507885, status_code: 0
# Starting the measurement!
# FoM: -0.020837762620037226, status_code: 0
# Starting the measurement!
# FoM: -0.020588551973003577, status_code: 0
# Starting the measurement!
# FoM: -0.020838527472958113, status_code: 0
# Starting the measurement!
# FoM: -0.020668635692285386, status_code: 0
# Starting the measurement!
# FoM: -0.02051705340459886, status_code: 0
# Starting the measurement!
# FoM: -0.020826358141298962, status_code: 0
# Starting the measurement!
# FoM: -0.02072710206534145, status_code: 0
# Starting the measurement!
# FoM: -0.020811494314227352, status_code: 0
# Starting the measurement!
# FoM: -0.020844296079257307, status_code: 0
# Starting the measurement!
# FoM: -0.020692132508900785, status_code: 0
# Starting the measurement!
# FoM: -0.020548754653077483, status_code: 0
# Starting the measurement!
# FoM: -0.020439238135790627, status_code: 0
# Starting the measurement!
# FoM: -0.020555850685405996, status_code: 0
# Starting the measurement!
# FoM: -0.020512104543329412, status_code: 0
# Starting the measurement!
# FoM: -0.020562370315392542, status_code: 0
# Starting the measurement!
# FoM: -0.020278414716214388, status_code: 0
# Starting the measurement!
# FoM: -0.02064894988599797, status_code: 0
# Starting the measurement!
# FoM: -0.0203716742283383, status_code: 0
# Starting the measurement!
# FoM: -0.02052200207389654, status_code: 0
# Starting the measurement!
# FoM: -0.02072325664303365, status_code: 0
# Starting the measurement!
# FoM: -0.020654024845217167, status_code: 0
# Starting the measurement!
# FoM: -0.020319328261657277, status_code: 0
# Starting the measurement!
# FoM: -0.020474710108282168, status_code: 0
# Starting the measurement!
# FoM: -0.020318381905625293, status_code: 0
# Starting the measurement!
# FoM: -0.020525272890607238, status_code: 0
# Starting the measurement!
# FoM: -0.02025280759306014, status_code: 0
# Starting the measurement!
# FoM: -0.020268309362271975, status_code: 0
# Starting the measurement!
# FoM: -0.02058868017178972, status_code: 0
# Starting the measurement!
# FoM: -0.020584875940228176, status_code: 0
# Starting the measurement!
# FoM: -0.020362371017686343, status_code: 0
# Starting the measurement!
# FoM: -0.020053676273378063, status_code: 0
# Starting the measurement!
# FoM: -0.02026449360070559, status_code: 0
# Starting the measurement!
# FoM: -0.02040692757342255, status_code: 0
# Starting the measurement!
# FoM: -0.020558119411152598, status_code: 0
# Starting the measurement!
# FoM: -0.020249039986563133, status_code: 0
# Starting the measurement!
# FoM: -0.020342165401384782, status_code: 0
# Starting the measurement!
# FoM: -0.020210261443606048, status_code: 0
# Starting the measurement!
# FoM: -0.020228719442684007, status_code: 0
# Starting the measurement!
# FoM: -0.02031234444596719, status_code: 0
# Starting the measurement!
# FoM: -0.02034741409290064, status_code: 0
# Starting the measurement!
# FoM: -0.02030698846058432, status_code: 0
# Starting the measurement!
# FoM: -0.020240401106387473, status_code: 0
# Starting the measurement!
# FoM: -0.020193313237578336, status_code: 0
# Starting the measurement!
# FoM: -0.020342693985735072, status_code: 0
# Starting the measurement!
# FoM: -0.020243204821646876, status_code: 0
# Starting the measurement!
# FoM: -0.019877418538044256, status_code: 0
# Starting the measurement!
# FoM: -0.020338343306319784, status_code: 0
# Starting the measurement!
# FoM: -0.020015408247469946, status_code: 0
# Starting the measurement!
# FoM: -0.02011809713134849, status_code: 0
# Starting the measurement!
# FoM: -0.020149790637328913, status_code: 0
# Starting the measurement!
# FoM: -0.020230153005075246, status_code: 0
# Starting the measurement!
# FoM: -0.020074176859791515, status_code: 0
# Starting the measurement!
# FoM: -0.02006303895557937, status_code: 0
# Starting the measurement!
# FoM: -0.020221163038941503, status_code: 0
# Starting the measurement!
# FoM: -0.020051157748729787, status_code: 0
# Starting the measurement!
# FoM: -0.01995574949745227, status_code: 0
# Starting the measurement!
# FoM: -0.020057563605296314, status_code: 0
# Starting the measurement!
# FoM: -0.020130785387235672, status_code: 0
# Starting the measurement!
# FoM: -0.019982984684691396, status_code: 0
# Starting the measurement!
# FoM: -0.019747066437212357, status_code: 0
# Starting the measurement!
# FoM: -0.020153159959657718, status_code: 0
# Starting the measurement!
# FoM: -0.02000390602548585, status_code: 0
# Starting the measurement!
# FoM: -0.020075449021464187, status_code: 0
# Starting the measurement!
# FoM: -0.01976368347208779, status_code: 0
# Starting the measurement!
# FoM: -0.02004942970132073, status_code: 0
# Starting the measurement!
# FoM: -0.01999029352579662, status_code: 0
# Starting the measurement!
# FoM: -0.019701556783618956, status_code: 0
# Starting the measurement!
# FoM: -0.020047784967807014, status_code: 0
# Starting the measurement!
# FoM: -0.020046757348541666, status_code: 0
# Starting the measurement!
# FoM: -0.019385199764999417, status_code: 0
# Starting the measurement!
# FoM: -0.01509765438975963, status_code: 0
# Starting the measurement!
# FoM: -0.019270268121475587, status_code: 0
# Starting the measurement!
# FoM: -0.018197085673630098, status_code: 0
# Starting the measurement!
# FoM: -0.017097442454065193, status_code: 0
# Starting the measurement!
# FoM: -0.019042801076171734, status_code: 0
# Starting the measurement!
# FoM: -0.019843574019408394, status_code: 0
# Starting the measurement!
# FoM: -0.018892425741939278, status_code: 0
# Starting the measurement!
# FoM: -0.019728970996295225, status_code: 0
# Starting the measurement!
# FoM: -0.019605249633972033, status_code: 0
# Starting the measurement!
# FoM: -0.01734938695522059, status_code: 0
# Starting the measurement!
# FoM: -0.019866086072983347, status_code: 0
# Starting the measurement!
# FoM: -0.01869275406637927, status_code: 0
# Starting the measurement!
# FoM: -0.019804032746891798, status_code: 0
# Starting the measurement!
# FoM: -0.0200995037922701, status_code: 0
# Starting the measurement!
# FoM: -0.019757923306847003, status_code: 0
# Starting the measurement!
# FoM: -0.019601081322734748, status_code: 0
# Starting the measurement!
# FoM: -0.019923031432283467, status_code: 0
# Starting the measurement!
# FoM: -0.019789036115587022, status_code: 0
# Starting the measurement!
# FoM: -0.01990047156002317, status_code: 0
# Starting the measurement!
# FoM: -0.01933360110423532, status_code: 0
# Starting the measurement!
# FoM: -0.019910696686016305, status_code: 0
# Starting the measurement!
# FoM: -0.01938074665806433, status_code: 0
# Starting the measurement!
# FoM: -0.019677230676605095, status_code: 0
# Starting the measurement!
# FoM: -0.01939287611689977, status_code: 0
# Starting the measurement!
# FoM: -0.020079105560717014, status_code: 0
# Starting the measurement!
# FoM: -0.019993969598525396, status_code: 0
# Starting the measurement!
# FoM: -0.019908844547591897, status_code: 0
# Starting the measurement!
# FoM: -0.01974888536287034, status_code: 0
# Starting the measurement!
# FoM: -0.019999335245002192, status_code: 0
# Starting the measurement!
# FoM: -0.019670865283440753, status_code: 0
# Starting the measurement!
# FoM: -0.01993883274591124, status_code: 0
# Starting the measurement!
# FoM: -0.019778939711755927, status_code: 0
# Starting the measurement!
# FoM: -0.0197679659916723, status_code: 0
# Starting the measurement!
# FoM: -0.019896857966293147, status_code: 0
# Starting the measurement!
# FoM: -0.019758796461648465, status_code: 0
# Starting the measurement!
# FoM: -0.019690587918651414, status_code: 0
# Starting the measurement!
# FoM: -0.019879707062596563, status_code: 0
# Starting the measurement!
# FoM: -0.02030588861633631, status_code: 0
# Starting the measurement!
# FoM: -0.01961695849770939, status_code: 0
# Starting the measurement!
# FoM: -0.019785587241077596, status_code: 0
# Starting the measurement!
# FoM: -0.019821969663837646, status_code: 0
# Starting the measurement!
# FoM: -0.01966257418111017, status_code: 0
# Starting the measurement!
# FoM: -0.019787523100609494, status_code: 0
# Starting the measurement!
# FoM: -0.01983988366886036, status_code: 0
# Starting the measurement!
# FoM: -0.019653562172484484, status_code: 0
# Starting the measurement!
# FoM: -0.01990990913449675, status_code: 0
# Starting the measurement!
# FoM: -0.01988141821964906, status_code: 0
# Starting the measurement!
# FoM: -0.019993740467566967, status_code: 0
# Starting the measurement!
# FoM: -0.019967514359689797, status_code: 0
# Starting the measurement!
# FoM: -0.019954740907748292, status_code: 0
# Starting the measurement!
# FoM: -0.020065518290842577, status_code: 0
# Starting the measurement!
# FoM: -0.019747919523026236, status_code: 0
# Starting the measurement!
# FoM: -0.019931947099815495, status_code: 0
# Starting the measurement!
# FoM: -0.01972740055420552, status_code: 0
# Starting the measurement!
# FoM: -0.019849550644103653, status_code: 0
# Starting the measurement!
# FoM: -0.019898756813476637, status_code: 0
# Starting the measurement!
# FoM: -0.019786626038943655, status_code: 0
# Starting the measurement!
# FoM: -0.019900372581260872, status_code: 0
# Starting the measurement!
# FoM: -0.019979469066866096, status_code: 0
# Starting the measurement!
# FoM: -0.019614144195736705, status_code: 0
# Starting the measurement!
# FoM: -0.01961901974369462, status_code: 0
# Starting the measurement!
# FoM: -0.01967240535975734, status_code: 0
# Starting the measurement!
# FoM: -0.019847498478062664, status_code: 0
# Starting the measurement!
# FoM: -0.019757580732599367, status_code: 0
# Starting the measurement!
# FoM: -0.019954808292202197, status_code: 0
# Starting the measurement!
# FoM: -0.019829116307687022, status_code: 0
# Starting the measurement!
# FoM: -0.019825715230356478, status_code: 0
# Starting the measurement!
# FoM: -0.0198377675182293, status_code: 0
# Starting the measurement!
# FoM: -0.01975142061237889, status_code: 0
# Starting the measurement!
# FoM: -0.01995901502723718, status_code: 0
# Starting the measurement!
# FoM: -0.01976697786920223, status_code: 0
# Starting the measurement!
# FoM: -0.019834059989223385, status_code: 0
# Starting the measurement!
# FoM: -0.019726644266858995, status_code: 0
# Starting the measurement!
# FoM: -0.019689575964308204, status_code: 0
# Starting the measurement!
# FoM: -0.01959056112954838, status_code: 0
# Starting the measurement!
# FoM: -0.01994668564047286, status_code: 0
# Starting the measurement!
# FoM: -0.0194049748381665, status_code: 0
# Starting the measurement!
# FoM: -0.01930340477926973, status_code: 0
# Starting the measurement!
# FoM: -0.019636707366215145, status_code: 0
# Starting the measurement!
# FoM: -0.019481863487508355, status_code: 0
# Starting the measurement!
# FoM: -0.019635448940019895, status_code: 0
# Starting the measurement!
# FoM: -0.01974228205761286, status_code: 0
# Starting the measurement!
# FoM: -0.01972435984675358, status_code: 0
# Starting the measurement!
# FoM: -0.01984777948470473, status_code: 0
# Starting the measurement!
# FoM: -0.01973583988587657, status_code: 0
# Starting the measurement!
# FoM: -0.019654183009260695, status_code: 0
# Starting the measurement!
# Stopping the measurement!
# Stopping the measurement!
# Optimization finished

# %%
# Access to the optimizer object to get info about the optimization
optimizer_obj = optimizationlogic.optimizer_obj

# %%
optimizer_obj

# %%
optimizer_obj.best_fom

# %%
# Best controls
pulses_list, time_grids_list, parameters_list = optimizer_obj.get_best_controls()
t_amplitude = time_grids_list[0]
amplitude = pulses_list[0]
t_phase = time_grids_list[1]
phase = pulses_list[1]
